# %%
from sklearn import tree
import pandas as pd
import os

# %% [markdown]
# # read in csv file and make dataframe

# %%
df = pd.read_csv('/Users/marlonschieber/Desktop/weather_api/model_input.csv')
df.head()
# Out:
#      date  aqi  precip  humidity  windspeed  winddir  acres_burned  temp_f  \
# 0  1/1/17   18     0.0        75         10      269           0.0      51
# 1  1/2/17    5     0.0        78          7      198           0.0      49
# 2  1/3/17    0     2.4        89         13      149           0.0      54
# 3  1/4/17   10     1.1        90          7      271           0.0      55
# 4  1/5/17   10     0.0        65          5      200           0.0      48
#
#    cloud_cover
# 0           51
# 1           49
# 2           54
# 3           55
# 4           48

# %% [markdown]
# # set aqi as target, remove unwanted columns, and set data variable

# %%
target = df["aqi"]

# %%
data = df.drop("date", axis=1)
data = data.drop("aqi", axis=1)
feature_names = data.columns
data.head()
# Out:
#    precip  humidity  windspeed  winddir  acres_burned  temp_f  cloud_cover
# 0     0.0        75         10      269           0.0      51           51
# 1     0.0        78          7      198           0.0      49           49
# 2     2.4        89         13      149           0.0      54           54
# 3     1.1        90          7      271           0.0      55           55
# 4     0.0        65          5      200           0.0      48           48

# %% [markdown]
# # split data and set x and y variables

# %%
 from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %% [markdown]
# # find score of decision tree, and random forest

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.03825136612021858

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.03278688524590164

# %% [markdown]
# # list order of importance of variables for tree and forest classifiers

# %%
 sorted(zip(clf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.23739808662108158, 'winddir'),
#  (0.20839354025969728, 'humidity'),
#  (0.13521720679028848, 'windspeed'),
#  (0.1297198437151778, 'cloud_cover'),
#  (0.12472005918976264, 'temp_f'),
#  (0.10842942354531834, 'acres_burned'),
#  (0.05612183987867385, 'precip')]

# %%
 sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.21652901436594674, 'winddir'),
#  (0.20161107914147688, 'humidity'),
#  (0.1470681934247492, 'temp_f'),
#  (0.1460900136349943, 'cloud_cover'),
#  (0.1296620801456762, 'windspeed'),
#  (0.09315167765510049, 'acres_burned'),
#  (0.06588794163205605, 'precip')]

# %% [markdown]
# # re-attempt model with a single variable to achieve a higher score

# %%
data = pd.DataFrame({
    'winddir': df['winddir']
})

feature_names = data.columns 
data.head()
# Out:
#    winddir
# 0      269
# 1      198
# 2      149
# 3      271
# 4      200

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.02185792349726776

# %% [markdown]
# # apply filter on dates, to run models on fire seasons only for both years

# %%
#  convert to datetime
df['date'] = pd.to_datetime(df['date'])

start_date = '06/30/2017'
end_date = '12/31/2017'

mask1 = (df['date'] > start_date) & (df['date'] <= end_date)


df1 = df.loc[mask1]
df1


df['date'] = pd.to_datetime(df['date'])

start_date = '06/30/2018'
end_date = '12/31/2018'

mask2 = (df['date'] > start_date) & (df['date'] <= end_date)


df2 = df.loc[mask2]
df2
# Out:
#           date  aqi  precip  humidity  windspeed  winddir  acres_burned  \
# 546 2018-07-01   17     0.0        70          6      244   6449.142857
# 547 2018-07-02   24     0.0        76          6      244   6449.142857
# 548 2018-07-03   54     0.1        73          7      224   6449.142857
# 549 2018-07-04   49     0.1        75          7      233   6449.142857
# 550 2018-07-05   32     0.0        67          5      258   9904.415584
# 551 2018-07-06   40     0.0        55          4      263   9904.415584
# 552 2018-07-07   42     0.0        54          6      262   9904.415584
# 553 2018-07-08   46     0.0        59          6      247   9904.415584
# 554 2018-07-09   44     0.0        53          6      257   9904.415584
# 564      80           80
# 565      79           79
# 566      79           79
# 567      78           78
# 568      79           79
# 569      78           78
# 570      84           84
# 571      78           78
# 572      74           74
# 573      79           79
# 574      76           76
# 575      78           78
# ..      ...          ...
# 700      50           50
# 701      52           52
# 702      50           50
# 703      50           50
# 704      55           55
# 705      53           53
# 706      53           53
# 707      53           53
# 708      50           50
# 709      53           53
# 710      56           56
# 711      53           53
# 712      53           53
# 713      57           57
# 714      56           56
# 715      53           53
# 716      55           55
# 717      57           57
# 718      54           54
# 719      53           53
# 720      53           53
# 721      53           53
# 722      53           53
# 723      52           52
# 724      54           54
# 725      52           52
# 726      53           53
# 727      53           53
# 728      53           53
# 729      53           53
#
# [184 rows x 9 columns]

# %%
final_df = pd.concat([df1, df2], ignore_index=True)
final_df
# Out:
#           date  aqi  precip  humidity  windspeed  winddir  acres_burned  \
# 0   2017-07-01   41     0.1        77          9      240    396.915663
# 1   2017-07-02   20     0.1        78          6      225    396.915663
# 2   2017-07-03   18     0.0        76          6      248    396.915663
# 3   2017-07-04   22     0.0        77          6      248    396.915663
# 4   2017-07-05    9     0.0        76          6      252    396.915663
# 5   2017-07-06   25     0.0        64          6      252    396.915663
# 6   2017-07-07   45     0.0        52          6      251    396.915663
# 7   2017-07-08   54     0.0        47          6      243    396.915663
# 8   2017-07-09   50     0.0        68          6      241    396.915663
# 9   2017-07-10   45     0.0        74          7      237    396.915663
# 10  2017-07-11   55     0.0        72          7      236   8770.215663
# 11  2017-07-12   39     0.0        73          6      241   8770.215663
# 12  2017-07-13   25     0.0        75          6      238   8770.215663
# 13  2017-07-14   34     0.0        72          6      237   8770.215663
# 14  2017-07-15   48     0.0        61          5      238   8770.215663
# 15  2017-07-16   57     0.0        44          6      249  10868.318230
# 16  2017-07-17   55     0.0        55          7      247  10868.318230
# 17  2017-07-18   40     0.1        76          8      240  10868.318230
# 18  2017-07-19   39     0.0        71          6      238  10868.318230
# 19  2017-07-20   47     0.0        71          6      237  10868.318230
# 20  2017-07-21   37     0.0        67          6      235  10868.318230
# 21  2017-07-22   42     0.0        59          4      226   2495.018227
# 22  2017-07-23   17     0.0        60          5      242   2495.018227
# 23  2017-07-24   18     0.0        71          5      237   6108.931270
# 24  2017-07-25   15     0.0        72          5      252   6108.931270
# 25  2017-07-26   19     0.0        72          5      258   6108.931270
# 26  2017-07-27   22     0.0        63          5      239   6108.931270
# 27  2017-07-28   41     0.0        68          6      236   6108.931270
# 28  2017-07-29   35     0.0        73          5      241   6108.931270
# 29  2017-07-30   15     0.1        71          5      247   6108.931270
# ..         ...  ...     ...       ...        ...      ...           ...
# 338 2018-12-02   21     0.0        76          6      128      0.000000
# 339 2018-12-03   30     0.0        75          7       58      0.000000
# 340 2018-12-04   40     3.7        80         10       64      0.000000
# 341 2018-12-05   32     1.4        87         11       51      0.000000
# 342 2018-12-06   47     0.0        79          7       49      0.000000
# 343 2018-12-07   54     0.0        76          3       43      0.000000
# 344 2018-12-08   70     0.0        81          5       52      0.000000
# 345 2018-12-09   76     0.0        85          3       53      0.000000
# 346 2018-12-10   74     0.4        88          4      127      0.000000
# 347 2018-12-11   54     0.0        81          4      200      0.000000
# 348 2018-12-12   55     0.0        78          6      170      0.000000
# 349 2018-12-13   58     0.0        66          6       64      0.000000
# 350 2018-12-14   63     3.6        77          7      133      0.000000
# 351 2018-12-15   50     4.0        88          5      144      0.000000
# 352 2018-12-16   26    14.5        86         10      164      0.000000
# 353 2018-12-17   38     1.2        85          5      244      0.000000
# 354 2018-12-18   45     0.0        91          3      206      0.000000
# 355 2018-12-19   45     0.0        91          4       56      0.000000
# 356 2018-12-20   64     0.0        90          3      117      0.000000
# 357 2018-12-21   46     1.2        88          5      198      0.000000
# 358 2018-12-22   35     0.0        80          4       86      0.000000
# 359 2018-12-23   51     0.3        85          3      232      0.000000
# 360 2018-12-24   48     1.3        95          9      194      0.000000
# 361 2018-12-25   28     0.8        75          9      312      0.000000
# 362 2018-12-26   27     0.0        74          5      297      0.000000
# 363 2018-12-27   19     0.0        71          9      283      0.000000
# 364 2018-12-28   23     0.0        52          9       21      0.000000
# 365 2018-12-29   39     0.0        59          3      121      0.000000
# 366 2018-12-30   56     0.0        79          4      176      0.000000
# 367 2018-12-31   12     0.0        56          9      117      0.000000
#
#      temp_f  cloud_cover
# 0        70           70
# 1        73           73
# 2        75           75
# 3        74           74
# 4        74           74
# 5        81           81
# 6        89           89
# 7        88           88
# 8        79           79
# 9        76           76
# 10       74           74
# 11       76           76
# 12       75           75
# 13       76           76
# 14       83           83
# 15       90           90
# 16       81           81
# 17       69           69
# 18       77           77
# 19       74           74
# 20       78           78
# 21       84           84
# 22       84           84
# 23       76           76
# 24       76           76
# 25       78           78
# 26       82           82
# 27       77           77
# 28       75           75
# 29       78           78
# ..      ...          ...
# 338      50           50
# 339      52           52
# 340      50           50
# 341      50           50
# 342      55           55
# 343      53           53
# 344      53           53
# 345      53           53
# 346      50           50
# 347      53           53
# 348      56           56
# 349      53           53
# 350      53           53
# 351      57           57
# 352      56           56
# 353      53           53
# 354      55           55
# 355      57           57
# 356      54           54
# 357      53           53
# 358      53           53
# 359      53           53
# 360      53           53
# 361      52           52
# 362      54           54
# 363      52           52
# 364      53           53
# 365      53           53
# 366      53           53
# 367      53           53
#
# [368 rows x 9 columns]

# %%
target = final_df["aqi"]

data = final_df.drop("date", axis=1)
data = data.drop("aqi", axis=1)
feature_names = data.columns
data.head()
# Out:
#    precip  humidity  windspeed  winddir  acres_burned  temp_f  cloud_cover
# 0     0.1        77          9      240    396.915663      70           70
# 1     0.1        78          6      225    396.915663      73           73
# 2     0.0        76          6      248    396.915663      75           75
# 3     0.0        77          6      248    396.915663      74           74
# 4     0.0        76          6      252    396.915663      74           74

# %% [markdown]
# # re-attempt models on fire seasons of both years to achieve higher score

# %%
 from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.05434782608695652

# %%
sorted(zip(clf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.24814703554835882, 'winddir'),
#  (0.16726012813787416, 'cloud_cover'),
#  (0.14576822580118948, 'humidity'),
#  (0.1380113067207116, 'acres_burned'),
#  (0.13104030963122604, 'temp_f'),
#  (0.11579890933489169, 'windspeed'),
#  (0.0539740848257483, 'precip')]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.06521739130434782

# %%
 sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.21652890249992165, 'winddir'),
#  (0.19176324385485097, 'humidity'),
#  (0.14200388819264892, 'cloud_cover'),
#  (0.14037224013265023, 'temp_f'),
#  (0.12858214438504578, 'acres_burned'),
#  (0.1183288660325556, 'windspeed'),
#  (0.062420714902326785, 'precip')]
